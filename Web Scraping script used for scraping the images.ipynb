# %% [markdown]
# # Data Scrapping

# %% [markdown]
# # Importing the required libraries:-

# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import requests

# %%
#activating the chrome browser
driver=webdriver.Chrome('chromedriver.exe')
#opening the home page of amazon.in
url="https://www.amazon.in/"
driver.get(url)

# %%
driver.find_element_by_xpath("//div[@class='nav-search-scope nav-sprite']").click()

# %%
#selection the clothing Acessores from drop boxes
driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[1]/div/div/select/option[14]").click()

# %% [markdown]
# # Srcapping the - Sarees (women):

# %%
#web lelemnt for the search box
driver.find_element_by_id('twotabsearchtextbox').send_keys('Sarees')

# %%
#web element for the submit button
driver.find_element_by_xpath("//div[@class='nav-search-submit nav-sprite']").click()

# %%
url=[]
for i in range(4):
    for u in driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']//img"):
        url.append(u.get_attribute('src'))

# %%
len(url)
# Out:
# 236

# %%
for i in range(len(url)):
    if i  >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 240))
    response= requests.get(url[i])
    file = open("D:\Data Trained\FlipRobo\prjoect image scrapping sept 14"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 240 images
# Downloading 1 of 240 images
# Downloading 2 of 240 images
# Downloading 3 of 240 images
# Downloading 4 of 240 images
# Downloading 5 of 240 images
# Downloading 6 of 240 images
# Downloading 7 of 240 images
# Downloading 8 of 240 images
# Downloading 9 of 240 images
# Downloading 10 of 240 images
# Downloading 11 of 240 images
# Downloading 12 of 240 images
# Downloading 13 of 240 images
# Downloading 14 of 240 images
# Downloading 15 of 240 images
# Downloading 16 of 240 images
# Downloading 17 of 240 images
# Downloading 18 of 240 images
# Downloading 19 of 240 images
# Downloading 20 of 240 images
# Downloading 21 of 240 images
# Downloading 22 of 240 images
# Downloading 23 of 240 images
# Downloading 24 of 240 images
# Downloading 25 of 240 images
# Downloading 26 of 240 images
# Downloading 27 of 240 images
# Downloading 28 of 240 images
# Downloading 29 of 240 images
# Downloading 30 of 240 images
# Downloading 31 of 240 images
# Downloading 32 of 240 images
# Downloading 33 of 240 images
# Downloading 34 of 240 images
# Downloading 35 of 240 images
# Downloading 36 of 240 images
# Downloading 37 of 240 images
# Downloading 38 of 240 images
# Downloading 39 of 240 images
# Downloading 40 of 240 images
# Downloading 41 of 240 images
# Downloading 42 of 240 images
# Downloading 43 of 240 images
# Downloading 44 of 240 images
# Downloading 45 of 240 images
# Downloading 46 of 240 images
# Downloading 47 of 240 images
# Downloading 48 of 240 images
# Downloading 49 of 240 images
# Downloading 50 of 240 images
# Downloading 51 of 240 images
# Downloading 52 of 240 images
# Downloading 53 of 240 images
# Downloading 54 of 240 images
# Downloading 55 of 240 images
# Downloading 56 of 240 images
# Downloading 57 of 240 images
# Downloading 58 of 240 images
# Downloading 59 of 240 images
# Downloading 60 of 240 images
# Downloading 61 of 240 images
# Downloading 62 of 240 images
# Downloading 63 of 240 images
# Downloading 64 of 240 images
# Downloading 65 of 240 images
# Downloading 66 of 240 images
# Downloading 67 of 240 images
# Downloading 68 of 240 images
# Downloading 69 of 240 images
# Downloading 70 of 240 images
# Downloading 71 of 240 images
# Downloading 72 of 240 images
# Downloading 73 of 240 images
# Downloading 74 of 240 images
# Downloading 75 of 240 images
# Downloading 76 of 240 images
# Downloading 77 of 240 images
# Downloading 78 of 240 images
# Downloading 79 of 240 images
# Downloading 80 of 240 images
# Downloading 81 of 240 images
# Downloading 82 of 240 images
# Downloading 83 of 240 images
# Downloading 84 of 240 images
# Downloading 85 of 240 images
# Downloading 86 of 240 images
# Downloading 87 of 240 images
# Downloading 88 of 240 images
# Downloading 89 of 240 images
# Downloading 90 of 240 images
# Downloading 91 of 240 images
# Downloading 92 of 240 images
# Downloading 93 of 240 images
# Downloading 94 of 240 images
# Downloading 95 of 240 images
# Downloading 96 of 240 images
# Downloading 97 of 240 images
# Downloading 98 of 240 images
# Downloading 99 of 240 images
# Downloading 100 of 240 images
# Downloading 101 of 240 images
# Downloading 102 of 240 images
# Downloading 103 of 240 images
# Downloading 104 of 240 images
# Downloading 105 of 240 images
# Downloading 106 of 240 images
# Downloading 107 of 240 images
# Downloading 108 of 240 images
# Downloading 109 of 240 images
# Downloading 110 of 240 images
# Downloading 111 of 240 images
# Downloading 112 of 240 images
# Downloading 113 of 240 images
# Downloading 114 of 240 images
# Downloading 115 of 240 images
# Downloading 116 of 240 images
# Downloading 117 of 240 images
# Downloading 118 of 240 images
# Downloading 119 of 240 images
# Downloading 120 of 240 images
# Downloading 121 of 240 images
# Downloading 122 of 240 images
# Downloading 123 of 240 images
# Downloading 124 of 240 images
# Downloading 125 of 240 images
# Downloading 126 of 240 images
# Downloading 127 of 240 images
# Downloading 128 of 240 images
# Downloading 129 of 240 images
# Downloading 130 of 240 images
# Downloading 131 of 240 images
# Downloading 132 of 240 images
# Downloading 133 of 240 images
# Downloading 134 of 240 images
# Downloading 135 of 240 images
# Downloading 136 of 240 images
# Downloading 137 of 240 images
# Downloading 138 of 240 images
# Downloading 139 of 240 images
# Downloading 140 of 240 images
# Downloading 141 of 240 images
# Downloading 142 of 240 images
# Downloading 143 of 240 images
# Downloading 144 of 240 images
# Downloading 145 of 240 images
# Downloading 146 of 240 images
# Downloading 147 of 240 images
# Downloading 148 of 240 images
# Downloading 149 of 240 images
# Downloading 150 of 240 images
# Downloading 151 of 240 images
# Downloading 152 of 240 images
# Downloading 153 of 240 images
# Downloading 154 of 240 images
# Downloading 155 of 240 images
# Downloading 156 of 240 images
# Downloading 157 of 240 images
# Downloading 158 of 240 images
# Downloading 159 of 240 images
# Downloading 160 of 240 images
# Downloading 161 of 240 images
# Downloading 162 of 240 images
# Downloading 163 of 240 images
# Downloading 164 of 240 images
# Downloading 165 of 240 images
# Downloading 166 of 240 images
# Downloading 167 of 240 images
# Downloading 168 of 240 images
# Downloading 169 of 240 images
# Downloading 170 of 240 images
# Downloading 171 of 240 images
# Downloading 172 of 240 images
# Downloading 173 of 240 images
# Downloading 174 of 240 images
# Downloading 175 of 240 images
# Downloading 176 of 240 images
# Downloading 177 of 240 images
# Downloading 178 of 240 images
# Downloading 179 of 240 images
# Downloading 180 of 240 images
# Downloading 181 of 240 images
# Downloading 182 of 240 images
# Downloading 183 of 240 images
# Downloading 184 of 240 images
# Downloading 185 of 240 images
# Downloading 186 of 240 images
# Downloading 187 of 240 images
# Downloading 188 of 240 images
# Downloading 189 of 240 images
# Downloading 190 of 240 images
# Downloading 191 of 240 images
# Downloading 192 of 240 images
# Downloading 193 of 240 images
# Downloading 194 of 240 images
# Downloading 195 of 240 images
# Downloading 196 of 240 images
# Downloading 197 of 240 images
# Downloading 198 of 240 images
# Downloading 199 of 240 images

# %% [markdown]
# # Srcapping the -	Trousers (men)

# %%
url="https://www.amazon.in/"
driver.get(url)

# %%
driver.find_element_by_xpath("//div[@class='nav-search-scope nav-sprite']").click()

# %%
#selection the clothing Acessores from drop boxes
driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[1]/div/div/select/option[14]").click()

# %%
#web lelemnt for the search box
driver.find_element_by_id('twotabsearchtextbox').send_keys('Trousers')

# %%
#web element for the submit button
driver.find_element_by_xpath("//div[@class='nav-search-submit nav-sprite']").click()

# %%
turl=[]
for i in range(4):
    for u in driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']//img"):
             turl.append(u.get_attribute('src'))

# %%
 len(turl)
# Out:
# 272

# %%
for i in range(len(turl)):
    if i  >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 240))
    response= requests.get(turl[i])
    file = open("D:\Data Trained\mens"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 240 images
# Downloading 1 of 240 images
# Downloading 2 of 240 images
# Downloading 3 of 240 images
# Downloading 4 of 240 images
# Downloading 5 of 240 images
# Downloading 6 of 240 images
# Downloading 7 of 240 images
# Downloading 8 of 240 images
# Downloading 9 of 240 images
# Downloading 10 of 240 images
# Downloading 11 of 240 images
# Downloading 12 of 240 images
# Downloading 13 of 240 images
# Downloading 14 of 240 images
# Downloading 15 of 240 images
# Downloading 16 of 240 images
# Downloading 17 of 240 images
# Downloading 18 of 240 images
# Downloading 19 of 240 images
# Downloading 20 of 240 images
# Downloading 21 of 240 images
# Downloading 22 of 240 images
# Downloading 23 of 240 images
# Downloading 24 of 240 images
# Downloading 25 of 240 images
# Downloading 26 of 240 images
# Downloading 27 of 240 images
# Downloading 28 of 240 images
# Downloading 29 of 240 images
# Downloading 30 of 240 images
# Downloading 31 of 240 images
# Downloading 32 of 240 images
# Downloading 33 of 240 images
# Downloading 34 of 240 images
# Downloading 35 of 240 images
# Downloading 36 of 240 images
# Downloading 37 of 240 images
# Downloading 38 of 240 images
# Downloading 39 of 240 images
# Downloading 40 of 240 images
# Downloading 41 of 240 images
# Downloading 42 of 240 images
# Downloading 43 of 240 images
# Downloading 44 of 240 images
# Downloading 45 of 240 images
# Downloading 46 of 240 images
# Downloading 47 of 240 images
# Downloading 48 of 240 images
# Downloading 49 of 240 images
# Downloading 50 of 240 images
# Downloading 51 of 240 images
# Downloading 52 of 240 images
# Downloading 53 of 240 images
# Downloading 54 of 240 images
# Downloading 55 of 240 images
# Downloading 56 of 240 images
# Downloading 57 of 240 images
# Downloading 58 of 240 images
# Downloading 59 of 240 images
# Downloading 60 of 240 images
# Downloading 61 of 240 images
# Downloading 62 of 240 images
# Downloading 63 of 240 images
# Downloading 64 of 240 images
# Downloading 65 of 240 images
# Downloading 66 of 240 images
# Downloading 67 of 240 images
# Downloading 68 of 240 images
# Downloading 69 of 240 images
# Downloading 70 of 240 images
# Downloading 71 of 240 images
# Downloading 72 of 240 images
# Downloading 73 of 240 images
# Downloading 74 of 240 images
# Downloading 75 of 240 images
# Downloading 76 of 240 images
# Downloading 77 of 240 images
# Downloading 78 of 240 images
# Downloading 79 of 240 images
# Downloading 80 of 240 images
# Downloading 81 of 240 images
# Downloading 82 of 240 images
# Downloading 83 of 240 images
# Downloading 84 of 240 images
# Downloading 85 of 240 images
# Downloading 86 of 240 images
# Downloading 87 of 240 images
# Downloading 88 of 240 images
# Downloading 89 of 240 images
# Downloading 90 of 240 images
# Downloading 91 of 240 images
# Downloading 92 of 240 images
# Downloading 93 of 240 images
# Downloading 94 of 240 images
# Downloading 95 of 240 images
# Downloading 96 of 240 images
# Downloading 97 of 240 images
# Downloading 98 of 240 images
# Downloading 99 of 240 images
# Downloading 100 of 240 images
# Downloading 101 of 240 images
# Downloading 102 of 240 images
# Downloading 103 of 240 images
# Downloading 104 of 240 images
# Downloading 105 of 240 images
# Downloading 106 of 240 images
# Downloading 107 of 240 images
# Downloading 108 of 240 images
# Downloading 109 of 240 images
# Downloading 110 of 240 images
# Downloading 111 of 240 images
# Downloading 112 of 240 images
# Downloading 113 of 240 images
# Downloading 114 of 240 images
# Downloading 115 of 240 images
# Downloading 116 of 240 images
# Downloading 117 of 240 images
# Downloading 118 of 240 images
# Downloading 119 of 240 images
# Downloading 120 of 240 images
# Downloading 121 of 240 images
# Downloading 122 of 240 images
# Downloading 123 of 240 images
# Downloading 124 of 240 images
# Downloading 125 of 240 images
# Downloading 126 of 240 images
# Downloading 127 of 240 images
# Downloading 128 of 240 images
# Downloading 129 of 240 images
# Downloading 130 of 240 images
# Downloading 131 of 240 images
# Downloading 132 of 240 images
# Downloading 133 of 240 images
# Downloading 134 of 240 images
# Downloading 135 of 240 images
# Downloading 136 of 240 images
# Downloading 137 of 240 images
# Downloading 138 of 240 images
# Downloading 139 of 240 images
# Downloading 140 of 240 images
# Downloading 141 of 240 images
# Downloading 142 of 240 images
# Downloading 143 of 240 images
# Downloading 144 of 240 images
# Downloading 145 of 240 images
# Downloading 146 of 240 images
# Downloading 147 of 240 images
# Downloading 148 of 240 images
# Downloading 149 of 240 images
# Downloading 150 of 240 images
# Downloading 151 of 240 images
# Downloading 152 of 240 images
# Downloading 153 of 240 images
# Downloading 154 of 240 images
# Downloading 155 of 240 images
# Downloading 156 of 240 images
# Downloading 157 of 240 images
# Downloading 158 of 240 images
# Downloading 159 of 240 images
# Downloading 160 of 240 images
# Downloading 161 of 240 images
# Downloading 162 of 240 images
# Downloading 163 of 240 images
# Downloading 164 of 240 images
# Downloading 165 of 240 images
# Downloading 166 of 240 images
# Downloading 167 of 240 images
# Downloading 168 of 240 images
# Downloading 169 of 240 images
# Downloading 170 of 240 images
# Downloading 171 of 240 images
# Downloading 172 of 240 images
# Downloading 173 of 240 images
# Downloading 174 of 240 images
# Downloading 175 of 240 images
# Downloading 176 of 240 images
# Downloading 177 of 240 images
# Downloading 178 of 240 images
# Downloading 179 of 240 images
# Downloading 180 of 240 images
# Downloading 181 of 240 images
# Downloading 182 of 240 images
# Downloading 183 of 240 images
# Downloading 184 of 240 images
# Downloading 185 of 240 images
# Downloading 186 of 240 images
# Downloading 187 of 240 images
# Downloading 188 of 240 images
# Downloading 189 of 240 images
# Downloading 190 of 240 images
# Downloading 191 of 240 images
# Downloading 192 of 240 images
# Downloading 193 of 240 images
# Downloading 194 of 240 images
# Downloading 195 of 240 images
# Downloading 196 of 240 images
# Downloading 197 of 240 images
# Downloading 198 of 240 images
# Downloading 199 of 240 images

# %% [markdown]
# # Srcapping the -Jeans (men):

# %%
url="https://www.amazon.in/"
driver.get(url)

# %%
driver.find_element_by_xpath("//div[@class='nav-search-scope nav-sprite']").click()

# %%
#selection the clothing Acessores from drop boxes
driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[1]/div/div/select/option[14]").click()

# %%
#web lelemnt for the search box
driver.find_element_by_id('twotabsearchtextbox').send_keys('jeans')

# %%
#web element for the submit button
driver.find_element_by_xpath("//div[@class='nav-search-submit nav-sprite']").click()

# %%
jurl=[]
for i in range(5):
    for u in driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']//img"):
             jurl.append(u.get_attribute('src'))

# %%
len(jurl)
# Out:
# 335

# %%
for i in range(len(jurl)):
    if i  >= 200:
        break
    print("Downloading {0} of {1} images" .format(i, 240))
    response= requests.get(jurl[i])
    file = open("D:\Data Trained\mens"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 240 images
# Downloading 1 of 240 images
# Downloading 2 of 240 images
# Downloading 3 of 240 images
# Downloading 4 of 240 images
# Downloading 5 of 240 images
# Downloading 6 of 240 images
# Downloading 7 of 240 images
# Downloading 8 of 240 images
# Downloading 9 of 240 images
# Downloading 10 of 240 images
# Downloading 11 of 240 images
# Downloading 12 of 240 images
# Downloading 13 of 240 images
# Downloading 14 of 240 images
# Downloading 15 of 240 images
# Downloading 16 of 240 images
# Downloading 17 of 240 images
# Downloading 18 of 240 images
# Downloading 19 of 240 images
# Downloading 20 of 240 images
# Downloading 21 of 240 images
# Downloading 22 of 240 images
# Downloading 23 of 240 images
# Downloading 24 of 240 images
# Downloading 25 of 240 images
# Downloading 26 of 240 images
# Downloading 27 of 240 images
# Downloading 28 of 240 images
# Downloading 29 of 240 images
# Downloading 30 of 240 images
# Downloading 31 of 240 images
# Downloading 32 of 240 images
# Downloading 33 of 240 images
# Downloading 34 of 240 images
# Downloading 35 of 240 images
# Downloading 36 of 240 images
# Downloading 37 of 240 images
# Downloading 38 of 240 images
# Downloading 39 of 240 images
# Downloading 40 of 240 images
# Downloading 41 of 240 images
# Downloading 42 of 240 images
# Downloading 43 of 240 images
# Downloading 44 of 240 images
# Downloading 45 of 240 images
# Downloading 46 of 240 images
# Downloading 47 of 240 images
# Downloading 48 of 240 images
# Downloading 49 of 240 images
# Downloading 50 of 240 images
# Downloading 51 of 240 images
# Downloading 52 of 240 images
# Downloading 53 of 240 images
# Downloading 54 of 240 images
# Downloading 55 of 240 images
# Downloading 56 of 240 images
# Downloading 57 of 240 images
# Downloading 58 of 240 images
# Downloading 59 of 240 images
# Downloading 60 of 240 images
# Downloading 61 of 240 images
# Downloading 62 of 240 images
# Downloading 63 of 240 images
# Downloading 64 of 240 images
# Downloading 65 of 240 images
# Downloading 66 of 240 images
# Downloading 67 of 240 images
# Downloading 68 of 240 images
# Downloading 69 of 240 images
# Downloading 70 of 240 images
# Downloading 71 of 240 images
# Downloading 72 of 240 images
# Downloading 73 of 240 images
# Downloading 74 of 240 images
# Downloading 75 of 240 images
# Downloading 76 of 240 images
# Downloading 77 of 240 images
# Downloading 78 of 240 images
# Downloading 79 of 240 images
# Downloading 80 of 240 images
# Downloading 81 of 240 images
# Downloading 82 of 240 images
# Downloading 83 of 240 images
# Downloading 84 of 240 images
# Downloading 85 of 240 images
# Downloading 86 of 240 images
# Downloading 87 of 240 images
# Downloading 88 of 240 images
# Downloading 89 of 240 images
# Downloading 90 of 240 images
# Downloading 91 of 240 images
# Downloading 92 of 240 images
# Downloading 93 of 240 images
# Downloading 94 of 240 images
# Downloading 95 of 240 images
# Downloading 96 of 240 images
# Downloading 97 of 240 images
# Downloading 98 of 240 images
# Downloading 99 of 240 images
# Downloading 100 of 240 images
# Downloading 101 of 240 images
# Downloading 102 of 240 images
# Downloading 103 of 240 images
# Downloading 104 of 240 images
# Downloading 105 of 240 images
# Downloading 106 of 240 images
# Downloading 107 of 240 images
# Downloading 108 of 240 images
# Downloading 109 of 240 images
# Downloading 110 of 240 images
# Downloading 111 of 240 images
# Downloading 112 of 240 images
# Downloading 113 of 240 images
# Downloading 114 of 240 images
# Downloading 115 of 240 images
# Downloading 116 of 240 images
# Downloading 117 of 240 images
# Downloading 118 of 240 images
# Downloading 119 of 240 images
# Downloading 120 of 240 images
# Downloading 121 of 240 images
# Downloading 122 of 240 images
# Downloading 123 of 240 images
# Downloading 124 of 240 images
# Downloading 125 of 240 images
# Downloading 126 of 240 images
# Downloading 127 of 240 images
# Downloading 128 of 240 images
# Downloading 129 of 240 images
# Downloading 130 of 240 images
# Downloading 131 of 240 images
# Downloading 132 of 240 images
# Downloading 133 of 240 images
# Downloading 134 of 240 images
# Downloading 135 of 240 images
# Downloading 136 of 240 images
# Downloading 137 of 240 images
# Downloading 138 of 240 images
# Downloading 139 of 240 images
# Downloading 140 of 240 images
# Downloading 141 of 240 images
# Downloading 142 of 240 images
# Downloading 143 of 240 images
# Downloading 144 of 240 images
# Downloading 145 of 240 images
# Downloading 146 of 240 images
# Downloading 147 of 240 images
# Downloading 148 of 240 images
# Downloading 149 of 240 images
# Downloading 150 of 240 images
# Downloading 151 of 240 images
# Downloading 152 of 240 images
# Downloading 153 of 240 images
# Downloading 154 of 240 images
# Downloading 155 of 240 images
# Downloading 156 of 240 images
# Downloading 157 of 240 images
# Downloading 158 of 240 images
# Downloading 159 of 240 images
# Downloading 160 of 240 images
# Downloading 161 of 240 images
# Downloading 162 of 240 images
# Downloading 163 of 240 images
# Downloading 164 of 240 images
# Downloading 165 of 240 images
# Downloading 166 of 240 images
# Downloading 167 of 240 images
# Downloading 168 of 240 images
# Downloading 169 of 240 images
# Downloading 170 of 240 images
# Downloading 171 of 240 images
# Downloading 172 of 240 images
# Downloading 173 of 240 images
# Downloading 174 of 240 images
# Downloading 175 of 240 images
# Downloading 176 of 240 images
# Downloading 177 of 240 images
# Downloading 178 of 240 images
# Downloading 179 of 240 images
# Downloading 180 of 240 images
# Downloading 181 of 240 images
# Downloading 182 of 240 images
# Downloading 183 of 240 images
# Downloading 184 of 240 images
# Downloading 185 of 240 images
# Downloading 186 of 240 images
# Downloading 187 of 240 images
# Downloading 188 of 240 images
# Downloading 189 of 240 images
# Downloading 190 of 240 images
# Downloading 191 of 240 images
# Downloading 192 of 240 images
# Downloading 193 of 240 images
# Downloading 194 of 240 images
# Downloading 195 of 240 images
# Downloading 196 of 240 images
# Downloading 197 of 240 images
# Downloading 198 of 240 images
# Downloading 199 of 240 images
